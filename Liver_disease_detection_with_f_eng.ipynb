# %%
import pandas as pd

# %%
df = pd.read_csv('Liverp.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#        Age of the patient Gender of the patient  Total Bilirubin  \
# 0                    65.0                Female              0.7
# 1                    62.0                  Male             10.9
# 2                    62.0                  Male              7.3
# 3                    58.0                  Male              1.0
# 4                    72.0                  Male              3.9
# ...                   ...                   ...              ...
# 30686                50.0                  Male              2.2
# 30687                55.0                  Male              2.9
# 30688                54.0                  Male              6.8
# 30689                48.0                Female              1.9
# 30690                30.0                  Male              3.1
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0                   0.1                          187.0
# 1                   5.5                          699.0
# ...

# %%
result_counts = df['Result'].value_counts()
result_counts
# Out:
# Result
# 1    21917
# 2     8774
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Age of the patient                        2
# Gender of the patient                   902
# Total Bilirubin                         648
# Direct Bilirubin                        561
#  Alkphos Alkaline Phosphotase           796
#  Sgpt Alamine Aminotransferase          538
# Sgot Aspartate Aminotransferase         462
# Total Protiens                          463
#  ALB Albumin                            494
# A/G Ratio Albumin and Globulin Ratio    559
# Result                                    0
# dtype: int64

# %%
object_columns = df.select_dtypes(include=['object']).columns
print(object_columns)
# Out:
# Index(['Gender of the patient'], dtype='object')

# %%
df['Gender of the patient'] = df['Gender of the patient'].fillna('Unknown')

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['Gender of the patient'] = label_encoder.fit_transform(df['Gender of the patient'])

gender_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Gender of the patient Mapping:", gender_mapping)
# Out:
# Gender of the patient Mapping: {'Female': 0, 'Male': 1, 'Unknown': 2}

# %%
df
# Out:
#        Age of the patient  Gender of the patient  Total Bilirubin  \
# 0                    65.0                      0              0.7
# 1                    62.0                      1             10.9
# 2                    62.0                      1              7.3
# 3                    58.0                      1              1.0
# 4                    72.0                      1              3.9
# ...                   ...                    ...              ...
# 30686                50.0                      1              2.2
# 30687                55.0                      1              2.9
# 30688                54.0                      1              6.8
# 30689                48.0                      0              1.9
# 30690                30.0                      1              3.1
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0                   0.1                          187.0
# 1                   5.5                          699.0
# ...

# %%
import pandas as pd
from scipy.stats import shapiro, normaltest

numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns


for col in numeric_columns:
    print(f"Testing normality for column: {col}")

    shapiro_stat, shapiro_p = shapiro(df[col].dropna())
    print(f"Shapiro-Wilk Test p-value: {shapiro_p:.5f}")
    if shapiro_p < 0.05:
        print(f"{col}: Shapiro-Wilk Test indicates non-normal distribution.\n")
    else:
        print(f"{col}: Shapiro-Wilk Test suggests normal distribution.\n")

    dagostino_stat, dagostino_p = normaltest(df[col].dropna())
    print(f"D’Agostino’s K-squared Test p-value: {dagostino_p:.5f}")
    if dagostino_p < 0.05:
        print(f"{col}: D’Agostino’s Test indicates non-normal distribution.\n")
    else:
        print(f"{col}: D’Agostino’s Test suggests normal distribution.\n")

    print("-" * 50)
# Out:
# Testing normality for column: Age of the patient
# Shapiro-Wilk Test p-value: 0.00000
# Age of the patient: Shapiro-Wilk Test indicates non-normal distribution.
#
# D’Agostino’s K-squared Test p-value: 0.00000
# Age of the patient: D’Agostino’s Test indicates non-normal distribution.
#
# --------------------------------------------------
# Testing normality for column: Gender of the patient
# Shapiro-Wilk Test p-value: 0.00000
# Gender of the patient: Shapiro-Wilk Test indicates non-normal distribution.
#
# D’Agostino’s K-squared Test p-value: 0.00000
# Gender of the patient: D’Agostino’s Test indicates non-normal distribution.
#
# --------------------------------------------------
# Testing normality for column: Total Bilirubin
# Shapiro-Wilk Test p-value: 0.00000
# Total Bilirubin: Shapiro-Wilk Test indicates non-normal distribution.
#
# D’Agostino’s K-squared Test p-value: 0.00000
# Total Bilirubin: D’Agostino’s Test indicates non-normal distribution.
#
# ...

# %%
import pandas as pd


def remove_outliers_iqr(df, target_column='Result'):

    df_cleaned = df.copy()


    Q1 = df_cleaned.quantile(0.25)
    Q3 = df_cleaned.quantile(0.75)


    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR


    for column in df_cleaned.columns:
        if column != target_column:
            df_cleaned = df_cleaned[(df_cleaned[column] >= lower_bound[column]) & (df_cleaned[column] <= upper_bound[column])]

    return df_cleaned


df = remove_outliers_iqr(df, target_column='Result')


print(df.shape)
# Out:
# (18877, 11)

# %%
df.isnull().sum()
# Out:
# Age of the patient                      0
# Gender of the patient                   0
# Total Bilirubin                         0
# Direct Bilirubin                        0
#  Alkphos Alkaline Phosphotase           0
#  Sgpt Alamine Aminotransferase          0
# Sgot Aspartate Aminotransferase         0
# Total Protiens                          0
#  ALB Albumin                            0
# A/G Ratio Albumin and Globulin Ratio    0
# Result                                  0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)

# %%
df['Result'] = df['Result'].replace({1: 0, 2: 1})

# %%
from scipy.stats import f_oneway


target = 'Result'
features = df.columns.difference([target])


significance_threshold = 0.05


anova_results = {}
for feature in features:

    groups = [df[feature][df[target] == category] for category in df[target].unique()]


    f_stat, p_val = f_oneway(*groups)
    anova_results[feature] = {'F-statistic': f_stat, 'p-value': p_val, 'significant': p_val < significance_threshold}

for feature, stats in anova_results.items():
    significance = "significant" if stats['significant'] else "not significant"
    print(f"Feature: {feature}, F-statistic: {stats['F-statistic']:.4f}, p-value: {stats['p-value']:.4e} - {significance}")
# Out:
# Feature: A/G Ratio Albumin and Globulin Ratio, F-statistic: 245.2761, p-value: 6.1691e-55 - significant
# Feature: Age of the patient, F-statistic: 1.3005, p-value: 2.5414e-01 - not significant
# Feature: Direct Bilirubin, F-statistic: 651.5210, p-value: 2.5859e-141 - significant
# Feature: Gender of the patient, F-statistic: 0.0507, p-value: 8.2192e-01 - not significant
# Feature: Sgot Aspartate Aminotransferase, F-statistic: 426.1424, p-value: 1.2147e-93 - significant
# Feature: Total Bilirubin, F-statistic: 604.5387, p-value: 2.0039e-131 - significant
# Feature: Total Protiens, F-statistic: 3.7831, p-value: 5.1788e-02 - not significant
# Feature:  ALB Albumin, F-statistic: 193.4909, p-value: 9.0464e-44 - significant
# Feature:  Alkphos Alkaline Phosphotase, F-statistic: 493.9976, p-value: 4.6699e-108 - significant
# Feature:  Sgpt Alamine Aminotransferase, F-statistic: 314.2568, p-value: 9.4918e-70 - significant

# %%
df
# Out:
#        Age of the patient  Gender of the patient  Total Bilirubin  \
# 0                    65.0                      0              0.7
# 3                    58.0                      1              1.0
# 4                    72.0                      1              3.9
# 5                    46.0                      1              1.8
# 7                    29.0                      0              0.9
# ...                   ...                    ...              ...
# 30676                23.0                      1              1.4
# 30678                22.0                      1              2.4
# 30679                74.0                      1              0.6
# 30687                55.0                      1              2.9
# 30689                48.0                      0              1.9
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0                   0.1                          187.0
# 3                   0.4                          182.0
# ...

# %%
df = df.drop(columns=['Total Protiens', 'Gender of the patient', 'Age of the patient'])

# %%
print(df.columns)
# Out:
# Index(['Total Bilirubin', 'Direct Bilirubin', ' Alkphos Alkaline Phosphotase',
#        ' Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase',
#        ' ALB Albumin', 'A/G Ratio Albumin and Globulin Ratio', 'Result'],
#       dtype='object')

# %%
def feature_engineering(df):

    df.columns = df.columns.str.strip()


    df['nf1_Bilirubin_to_Albumin_Ratio'] = df['Total Bilirubin'] / df['ALB Albumin']
    df['nf2_Direct_to_Total_Bilirubin_Ratio'] = df['Direct Bilirubin'] / df['Total Bilirubin']
    df['nf3_SGPT_to_SGOT_Ratio'] = df['Sgpt Alamine Aminotransferase'] / df['Sgot Aspartate Aminotransferase']



    df['nf4_Bilirubin_Protein_Indicator'] = (df['Total Bilirubin'] > 1.0).astype(int)
    df['nf5_Total_Enzyme_Activity'] = df['Sgpt Alamine Aminotransferase'] + df['Sgot Aspartate Aminotransferase']

    return df


feature_engineering(df)


print(df[['nf1_Bilirubin_to_Albumin_Ratio', 'nf2_Direct_to_Total_Bilirubin_Ratio', 'nf3_SGPT_to_SGOT_Ratio',
          'nf4_Bilirubin_Protein_Indicator', 'nf5_Total_Enzyme_Activity']].head())
# Out:
#    nf1_Bilirubin_to_Albumin_Ratio  nf2_Direct_to_Total_Bilirubin_Ratio  \
# 0                        0.212121                             0.142857
# 3                        0.294118                             0.400000
# 4                        1.625000                             0.512821
# 5                        0.409091                             0.388889
# 7                        0.250000                             0.333333
#
#    nf3_SGPT_to_SGOT_Ratio  nf4_Bilirubin_Protein_Indicator  \
# 0                0.888889                                0
# 3                0.700000                                0
# 4                0.457627                                1
# 5                1.357143                                1
# 7                1.272727                                0
#
#    nf5_Total_Enzyme_Activity
# 0                       34.0
# 3                       34.0
# 4                       86.0
# 5                       33.0
# 7                       25.0

# %%
df.head(5)
# Out:
#    Total Bilirubin  Direct Bilirubin  Alkphos Alkaline Phosphotase  \
# 0              0.7               0.1                         187.0
# 3              1.0               0.4                         182.0
# 4              3.9               2.0                         195.0
# 5              1.8               0.7                         208.0
# 7              0.9               0.3                         202.0
#
#    Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 0                           16.0                             18.0
# 3                           14.0                             20.0
# 4                           27.0                             59.0
# 5                           19.0                             14.0
# 7                           14.0                             11.0
#
#    ALB Albumin  A/G Ratio Albumin and Globulin Ratio  Result  \
# 0          3.3                                   0.9       0
# ...

# %%
from sklearn.preprocessing import StandardScaler


columns_to_standardize = df.columns[df.columns != 'Result']


scaler = StandardScaler()


df[columns_to_standardize] = scaler.fit_transform(df[columns_to_standardize])

# %%
from sklearn.model_selection import train_test_split


train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)


print(f"Training set shape: {train_df.shape}")
print(f"Test set shape: {test_df.shape}")
# Out:
# Training set shape: (15101, 13)
# Test set shape: (3776, 13)

# %%
train_result_counts = train_df['Result'].value_counts()
test_result_counts = test_df['Result'].value_counts()

print("Value counts of 'Result' in train_df:")
print(train_result_counts)

print("\nValue counts of 'Result' in test_df:")
print(test_result_counts)
# Out:
# Value counts of 'Result' in train_df:
# Result
# 0    9321
# 1    5780
# Name: count, dtype: int64
#
# Value counts of 'Result' in test_df:
# Result
# 0    2362
# 1    1414
# Name: count, dtype: int64

# %%
# !pip install imbalanced-learn

# %%
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split


X_train = train_df.drop(columns=['Result'])
y_train = train_df['Result']

ros = RandomOverSampler(random_state=42)

X_resampled, y_resampled = ros.fit_resample(X_train, y_train)


train_df_resampled = X_resampled.copy()
train_df_resampled['Result'] = y_resampled

print(y_resampled.value_counts())
# Out:
# Result
# 0    9321
# 1    9321
# Name: count, dtype: int64

# %%
train_df_resampled
# Out:
#        Total Bilirubin  Direct Bilirubin  Alkphos Alkaline Phosphotase  \
# 0            -0.618969         -0.530543                     -0.325878
# 1            -0.505352         -0.530543                     -0.849904
# 2            -0.505352         -0.530543                      2.321829
# 3            -0.505352         -0.530543                      0.970395
# 4             1.653375          1.475559                      2.114977
# ...                ...               ...                           ...
# 18637        -0.505352         -0.530543                     -0.270718
# 18638        -0.618969         -0.530543                     -0.270718
# 18639        -0.618969         -0.530543                      0.349839
# 18640        -0.505352         -0.530543                     -0.187977
# 18641        -0.278117         -0.329933                     -0.670632
#
#        Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# ...

# %%
from google.colab import files
train_df_resampled.to_csv('train_df_resampled.csv', index=False)
files.download('train_df_resampled.csv')

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import matplotlib.pyplot as plt


X_train = train_df_resampled.drop(columns=['Result'])
y_train = train_df_resampled['Result']


model = RandomForestClassifier(random_state=42)


model.fit(X_train, y_train)


feature_importance = model.feature_importances_


importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importance})


importance_df = importance_df.sort_values(by='Importance', ascending=False)


print(importance_df)
# Out:
#                                  Feature  Importance
# 2           Alkphos Alkaline Phosphotase    0.133882
# 9                 nf3_SGPT_to_SGOT_Ratio    0.113745
# 7         nf1_Bilirubin_to_Albumin_Ratio    0.111546
# 11             nf5_Total_Enzyme_Activity    0.103200
# 4        Sgot Aspartate Aminotransferase    0.096603
# 3          Sgpt Alamine Aminotransferase    0.090102
# 5                            ALB Albumin    0.086857
# 8    nf2_Direct_to_Total_Bilirubin_Ratio    0.079943
# 6   A/G Ratio Albumin and Globulin Ratio    0.069745
# 0                        Total Bilirubin    0.067960
# 1                       Direct Bilirubin    0.041456
# 10       nf4_Bilirubin_Protein_Indicator    0.004962

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
import warnings
import time
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

warnings.filterwarnings('ignore', category=UserWarning, message='No further splits with positive gain, best gain: -inf')


X_train_resampled = train_df_resampled.drop(columns=['Result'])
y_train_resampled = train_df_resampled['Result']


param_grids = {
    'DecisionTree': {
        'criterion': ['gini', 'entropy'],
        'max_depth': [5, 10, 15],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 5]
    },
    'ExtraTrees': {
        'n_estimators': [50, 100, 200],
        'criterion': ['gini', 'entropy'],
        'max_depth': [10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 5]
    },
    'XGB': {
        'n_estimators': [100, 200],
        'max_depth': [3, 5, 7],
        'learning_rate': [0.01, 0.1, 0.2]
    },
    'LGB': {
        'n_estimators': [100, 200],
        'max_depth': [3, 5, 7],
        'learning_rate': [0.01, 0.1, 0.2],
        'feature_fraction': [0.8, 0.9],
        'bagging_fraction': [0.8, 0.9],
        'min_data_in_leaf': [10, 20, 30]
    },
    'RandomForest': {
        'n_estimators': [100, 200],
        'max_depth': [5, 10, 15],
        'min_samples_split': [5, 10],
        'class_weight': ['balanced']
    },
    'KNN': {
        'n_neighbors': [3, 5, 7],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan']
    },
    'MLP': {
        'hidden_layer_sizes': [(50,), (100,), (100, 50)],
        'activation': ['relu', 'tanh'],
        'max_iter': [200, 500,1000,5000]
    },
    'SVC': {
        'C': [1,2,3, 4, 10],
        'gamma': ['scale', 'auto'],
        'kernel': ['linear', 'rbf'],
        'class_weight': ['balanced', None]
    }
}


model_classes = {
    'DecisionTree': DecisionTreeClassifier,
    'ExtraTrees': ExtraTreesClassifier,
    'XGB': xgb.XGBClassifier,
    'LGB': lgb.LGBMClassifier,
    'RandomForest': RandomForestClassifier,
    'KNN': KNeighborsClassifier,
    'MLP': MLPClassifier,
    'SVC': SVC
}


for model_name, params in param_grids.items():
    print(f"Starting Grid Search for {model_name}...")

    model_cls = model_classes[model_name]
    model = model_cls()


    grid_search = GridSearchCV(model, params, cv=10, scoring='accuracy', verbose=0, n_jobs=-1)
    grid_search.fit(X_train_resampled, y_train_resampled)


    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_
    y_train_pred = best_model.predict(X_train_resampled)
    accuracy = accuracy_score(y_train_resampled, y_train_pred)

    print(f"Best Parameters for {model_name}: {best_params}")
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# Starting Grid Search for DecisionTree...
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters for DecisionTree: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Starting Grid Search for ExtraTrees...
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# ...

# %%
import warnings
import time
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.metrics import classification_report, accuracy_score

warnings.filterwarnings('ignore', category=UserWarning, message='No further splits with positive gain, best gain: -inf')


X_train_resampled = train_df_resampled.drop(columns=['Result'])
y_train_resampled = train_df_resampled['Result']


models = [
    DecisionTreeClassifier(
        criterion='gini',
        max_depth=10,
        min_samples_leaf=1,
        min_samples_split=2,
        random_state=42
    ),
    ExtraTreesClassifier(
        criterion='gini',
        max_depth=20,
        min_samples_leaf=1,
        min_samples_split=2,
        n_estimators=50,
        random_state=42
    ),
    xgb.XGBClassifier(
        n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    objective='binary:logistic',
    reg_alpha=0.5,
    reg_lambda=0.5,
    random_state=42
    ),
    lgb.LGBMClassifier(
        bagging_fraction=0.8,
        feature_fraction=0.8,
        learning_rate=0.1,
        max_depth=5,
        min_data_in_leaf=10,
        n_estimators=100,
        objective='binary',
        random_state=42,
        min_split_gain=0.01
    ),
    RandomForestClassifier(
        class_weight='balanced',
        max_depth=15,
        min_samples_split=5,
        n_estimators=100,
        random_state=42
    ),
    KNeighborsClassifier(
        metric='euclidean',
        n_neighbors=3,
        weights='uniform'
    ),
    MLPClassifier(
        activation='relu',
        hidden_layer_sizes=(100, 50),
        max_iter=200,
        random_state=42
    ),
    SVC(
        C=10,
        class_weight='balanced',
        gamma='scale',
        kernel='rbf',
        probability=True,
        random_state=42
    ),
    VotingClassifier(
        estimators=[
            ('rf', RandomForestClassifier(
                class_weight='balanced', max_depth=15, min_samples_split=5, n_estimators=100, random_state=42)),
            ('knn', KNeighborsClassifier(metric='euclidean', n_neighbors=3, weights='uniform')),
            ('svc', SVC(C=10, class_weight='balanced', gamma='scale', kernel='rbf', probability=True, random_state=42))
        ],
        voting='soft'
    )
]


for model in models:
    try:
        start_time = time.time()


        model.fit(X_train_resampled, y_train_resampled)


        end_time = time.time()
        training_time = end_time - start_time

        y_train_pred = model.predict(X_train_resampled)
        train_classification_report = classification_report(y_train_resampled, y_train_pred)
        accuracy = accuracy_score(y_train_resampled, y_train_pred)

        print(f"Training Time for {model.__class__.__name__}: {training_time:.4f} seconds")
        print(f"Accuracy for {model.__class__.__name__} on Training Set: {accuracy:.4f}")
        print(f"Classification Report for {model.__class__.__name__} on Training Set:")
        print(train_classification_report)
        print("=" * 80)

    except Exception as e:
        print(f"Error training {model.__class__.__name__}: {e}")
# Out:
# Training Time for DecisionTreeClassifier: 0.0375 seconds
# Accuracy for DecisionTreeClassifier on Training Set: 0.9434
# Classification Report for DecisionTreeClassifier on Training Set:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      9321
#            1       0.93      0.96      0.94      9321
#
#     accuracy                           0.94     18642
#    macro avg       0.94      0.94      0.94     18642
# weighted avg       0.94      0.94      0.94     18642
#
# ...
# Training Time for ExtraTreesClassifier: 0.4680 seconds
# Accuracy for ExtraTreesClassifier on Training Set: 0.9999
# Classification Report for ExtraTreesClassifier on Training Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9321
#            1       1.00      1.00      1.00      9321
#
#     accuracy                           1.00     18642
#    macro avg       1.00      1.00      1.00     18642
# ...

# %%
pip install lime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=3b46d6d363bdf35881d10bf58e9b3e0039d85d7086ae1fea4e85d1a2486f87ad
#   Stored in directory: /root/.cache/pip/wheels/fd/a2/af/9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# ...

# %%
import shap
import matplotlib.pyplot as plt

xgboost_model = models[2]


explainer = shap.Explainer(xgboost_model, X_train_resampled)


shap_values = explainer(X_train_resampled)


shap.summary_plot(shap_values, X_train_resampled)

shap.summary_plot(shap_values, X_train_resampled, plot_type="bar")
# Out:
#  99%|===================| 18427/18642 [00:58<00:00]

# %%
import shap
import time
import xgboost as xgb
from sklearn.metrics import classification_report, accuracy_score

explainer = shap.Explainer(xgboost_model, X_train_resampled)
shap_values = explainer(X_train_resampled)


shap.force_plot(
    base_value=explainer.expected_value,
    shap_values=shap_values[0].values,
    features=X_train_resampled.iloc[0, :],
    feature_names=X_train_resampled.columns,
    matplotlib=True,
    figsize=(20, 8),
    text_rotation=30
)
# Out:
#  99%|===================| 18398/18642 [00:58<00:00]

# %%
import shap
import matplotlib.pyplot as plt
import xgboost as xgb

xgboost_model = xgb.XGBClassifier(
    n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    objective='binary:logistic',
    reg_alpha=0.5,
    reg_lambda=0.5,
    random_state=42
)


xgboost_model.fit(X_train_resampled, y_train_resampled)


explainer = shap.Explainer(xgboost_model, X_train_resampled)

shap_values = explainer(X_train_resampled)


shap.force_plot(
    base_value=explainer.expected_value,
    shap_values=shap_values[17].values,
    features=X_train_resampled.iloc[17, :],
    feature_names=X_train_resampled.columns,
    matplotlib=True,
    figsize=(20, 8),
    text_rotation=30
)

plt.show()
# Out:
# 100%|===================| 18594/18642 [01:14<00:00]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold


models = [
    DecisionTreeClassifier(
        criterion='gini',
        max_depth=10,
        min_samples_leaf=1,
        min_samples_split=2,
        random_state=42
    ),
    ExtraTreesClassifier(
        criterion='gini',
        max_depth=20,
        min_samples_leaf=1,
        min_samples_split=2,
        n_estimators=50,
        random_state=42
    ),
    xgb.XGBClassifier(
        n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    objective='binary:logistic',
    reg_alpha=0.5,
    reg_lambda=0.5,
    random_state=42
    ),
    lgb.LGBMClassifier(
        n_estimators=100,
        max_depth=5,
        learning_rate=0.1,
        objective='binary',
        random_state=42,
        min_split_gain=0.01,
        feature_fraction=0.8,
        bagging_fraction=0.8,
        min_data_in_leaf=20
    ),
    RandomForestClassifier(
        n_estimators=100,
        max_depth=15,
        min_samples_split=5,
        class_weight='balanced',
        random_state=42
    ),
    KNeighborsClassifier(n_neighbors=3, metric='euclidean', weights='uniform'),
    MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=200, activation='relu', random_state=42),
    SVC(
        probability=True,
        random_state=42,
        C=10,
        class_weight='balanced',
        kernel='rbf',
        gamma='scale'
    ),
    VotingClassifier(
        estimators=[
            ('rf', RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=10, class_weight='balanced', random_state=42)),
            ('knn', KNeighborsClassifier(n_neighbors=5)),
            ('svc', SVC(probability=True, random_state=42, C=4, class_weight='balanced', kernel='rbf', gamma='scale'))
        ],
        voting='soft'
    )
]


kf = KFold(n_splits=10, shuffle=True, random_state=42)

for model in models:
    try:

        cv_scores = cross_val_score(model, X_train_resampled, y_train_resampled, cv=kf, scoring='accuracy')


        mean_cv_score = cv_scores.mean()
        std_cv_score = cv_scores.std()

        print(f"Model: {model.__class__.__name__}")
        print(f"Average Accuracy: {mean_cv_score:.4f} ± {std_cv_score:.4f}")
        print("=" * 80)

    except Exception as e:
        print(f"Error in cross-validation for {model.__class__.__name__}: {e}")
# Out:
# Model: DecisionTreeClassifier
# Average Accuracy: 0.9356 ± 0.0306
# ...
# Model: ExtraTreesClassifier
# Average Accuracy: 0.9999 ± 0.0002
# ...
# Model: XGBClassifier
# Average Accuracy: 0.9998 ± 0.0002
# ...
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# ...

# %%
import warnings
import time
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.metrics import classification_report, accuracy_score

warnings.filterwarnings('ignore', category=UserWarning, message='No further splits with positive gain, best gain: -inf')


X_train_resampled = train_df_resampled.drop(columns=['Result'])
y_train_resampled = train_df_resampled['Result']


X_test = test_df.drop(columns=['Result'])
y_test = test_df['Result']

models = [
    DecisionTreeClassifier(
        criterion='gini',
        max_depth=10,
        min_samples_leaf=1,
        min_samples_split=2,
        random_state=42
    ),
    ExtraTreesClassifier(
        criterion='gini',
        max_depth=20,
        min_samples_leaf=1,
        min_samples_split=2,
        n_estimators=50,
        random_state=42
    ),
    xgb.XGBClassifier(
        nn_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    objective='binary:logistic',
    reg_alpha=0.5,
    reg_lambda=0.5,
    random_state=42
    ),
    lgb.LGBMClassifier(
        bagging_fraction=0.8,
        feature_fraction=0.8,
        learning_rate=0.1,
        max_depth=5,
        min_data_in_leaf=10,
        n_estimators=100,
        objective='binary',
        random_state=42,
        min_split_gain=0.01
    ),
    RandomForestClassifier(
        class_weight='balanced',
        max_depth=15,
        min_samples_split=5,
        n_estimators=100,
        random_state=42
    ),
    KNeighborsClassifier(
        metric='euclidean',
        n_neighbors=3,
        weights='uniform'
    ),
    MLPClassifier(
        activation='relu',
        hidden_layer_sizes=(100, 50),
        max_iter=200,
        random_state=42
    ),
    SVC(
        C=10,
        class_weight='balanced',
        gamma='scale',
        kernel='rbf',
        probability=True,
        random_state=42
    ),
    VotingClassifier(
        estimators=[('rf', RandomForestClassifier(
            class_weight='balanced', max_depth=15, min_samples_split=5, n_estimators=100, random_state=42)),
            ('knn', KNeighborsClassifier(metric='euclidean', n_neighbors=3, weights='uniform')),
            ('svc', SVC(C=10, class_weight='balanced', gamma='scale', kernel='rbf', probability=True, random_state=42))
        ],
        voting='soft'
    )
]


for model in models:
    try:
        start_time = time.time()


        model.fit(X_train_resampled, y_train_resampled)

        end_time = time.time()
        training_time = end_time - start_time


        y_test_pred = model.predict(X_test)


        accuracy = accuracy_score(y_test, y_test_pred)
        test_classification_report = classification_report(y_test, y_test_pred)


        print(f"Training Time for {model.__class__.__name__}: {training_time:.4f} seconds")
        print(f"Accuracy for {model.__class__.__name__} on Test Set: {accuracy:.4f}")
        print(f"Classification Report for {model.__class__.__name__} on Test Set:")
        print(test_classification_report)
        print("=" * 80)

    except Exception as e:
        print(f"Error testing {model.__class__.__name__}: {e}")
# Out:
# Training Time for DecisionTreeClassifier: 0.0517 seconds
# Accuracy for DecisionTreeClassifier on Test Set: 0.9362
# Classification Report for DecisionTreeClassifier on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.95      2362
#            1       0.88      0.96      0.92      1414
#
#     accuracy                           0.94      3776
#    macro avg       0.93      0.94      0.93      3776
# weighted avg       0.94      0.94      0.94      3776
#
# ...
# Training Time for ExtraTreesClassifier: 0.4676 seconds
# Accuracy for ExtraTreesClassifier on Test Set: 1.0000
# Classification Report for ExtraTreesClassifier on Test Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2362
#            1       1.00      1.00      1.00      1414
#
#     accuracy                           1.00      3776
#    macro avg       1.00      1.00      1.00      3776
# ...

# %%
from sklearn.metrics import cohen_kappa_score, brier_score_loss


kappa_brier_results = {}


for model in models:
    try:

        y_test_pred = model.predict(X_test)
        y_test_prob = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None


        kappa = cohen_kappa_score(y_test, y_test_pred)


        brier_score = brier_score_loss(y_test, y_test_prob) if y_test_prob is not None else None


        kappa_brier_results[model.__class__.__name__] = {"Kappa": kappa, "Brier": brier_score}

        print(f"{model.__class__.__name__}:")
        print(f"Cohen's Kappa: {kappa:.4f}")
        print(f"Brier Score: {brier_score:.4f}" if brier_score is not None else "Brier Score: Not Available")
        print("=" * 80)

    except Exception as e:
        print(f"Error testing {model.__class__.__name__}: {e}")
# Out:
# DecisionTreeClassifier:
# Cohen's Kappa: 0.8661
# Brier Score: 0.0435
# ...
# ExtraTreesClassifier:
# Cohen's Kappa: 1.0000
# Brier Score: 0.0032
# ...
# XGBClassifier:
# Cohen's Kappa: 1.0000
# Brier Score: 0.0131
# ...
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# LGBMClassifier:
# Cohen's Kappa: 0.9994
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc
import seaborn as sns
import numpy as np


X_test = test_df.drop(columns=['Result'])
y_test = test_df['Result']


models = {
    'DecisionTree': DecisionTreeClassifier(criterion='gini', max_depth=10, random_state=42),
    'ExtraTrees': ExtraTreesClassifier(criterion='gini', max_depth=20, n_estimators=50, random_state=42),
    'XGB': xgb.XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.1, objective='binary:logistic', reg_alpha=0.5,
    reg_lambda=0.5, random_state=42),
    'LGB': lgb.LGBMClassifier(bagging_fraction=0.8, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_data_in_leaf=10, n_estimators=100, random_state=42),
    'RandomForest': RandomForestClassifier(class_weight='balanced', max_depth=15, min_samples_split=5, n_estimators=100, random_state=42),
    'KNN': KNeighborsClassifier(metric='euclidean', n_neighbors=3, weights='uniform'),
    'MLP': MLPClassifier(activation='relu', hidden_layer_sizes=(100, 50), max_iter=200, random_state=42),
    'SVC': SVC(C=10, class_weight='balanced', gamma='scale', kernel='rbf', probability=True, random_state=42),
    'VotingClassifier': VotingClassifier(estimators=[
        ('rf', RandomForestClassifier(class_weight='balanced', max_depth=15, min_samples_split=5, n_estimators=100, random_state=42)),
        ('knn', KNeighborsClassifier(metric='euclidean', n_neighbors=3, weights='uniform')),
        ('svc', SVC(C=10, class_weight='balanced', gamma='scale', kernel='rbf', probability=True, random_state=42))
    ], voting='soft')
}


fig, axs = plt.subplots(3, 3, figsize=(15, 15))
axs = axs.flatten()


for idx, (model_name, model) in enumerate(models.items()):

    model.fit(X_train_resampled, y_train_resampled)
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]


    cm = confusion_matrix(y_test, y_pred)
    ax = axs[idx]
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Disease', 'Disease'], yticklabels=['No Disease', 'Disease'], ax=ax)
    ax.set_title(f'{model_name} - Confusion Matrix')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True Label')

plt.tight_layout()
plt.show()


fig, axs = plt.subplots(3, 3, figsize=(15, 15))
axs = axs.flatten()


for idx, (model_name, model) in enumerate(models.items()):

    model.fit(X_train_resampled, y_train_resampled)
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]

    fpr, tpr, _ = roc_curve(y_test, y_prob)
    roc_auc = auc(fpr, tpr)


    ax = axs[idx]
    ax.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    ax.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(f'{model_name} - ROC Curve')
    ax.legend(loc="lower right")

plt.tight_layout()
plt.show()
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Info] Number of positive: 9321, number of negative: 9321
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002503 seconds.
# ...

# %% [markdown]
# **ERGERG**

# %% [markdown]
# **10 FOLD CV**
